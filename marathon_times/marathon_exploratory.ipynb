# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import bokeh.plotting
import bokeh.io

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
path = r'data/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, encoding= 'unicode_escape')
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
df.head(3)
# Out:
#    Year         Athlete   Country     Time Marathon
# 0  2019   Ashete Bekere  Ethiopia  2:20:14   Berlin
# 1  2018  Gladys Cherono     Kenya  2:18:11   Berlin
# 2  2017  Gladys Cherono     Kenya  2:20:23   Berlin

# %% [markdown]
# **What questions do I want answered?**
# - Make a plot with all marathons, in different colors, on the same axis. Make a plot for men and women.

# %%
p = bokeh.plotting.figure(
    width=400,
    height=300,
    x_axis_label='Year',
    y_axis_label='Time'
)

# %%
df.plot('Time')

# %%
# %load_ext watermark
# %watermark -v -p numpy,pandas,matplotlib,jupyterlab
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# CPython 3.7.7
# IPython 5.8.0
#
# numpy 1.18.1
# pandas 1.0.2
# matplotlib 3.1.3
# jupyterlab 1.2.4
